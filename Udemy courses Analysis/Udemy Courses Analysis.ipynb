# %% [markdown]
# ## Udemy Course Analysis

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
udemy = pd.read_csv("C:\\Users\\jnave\\OneDrive\\Documents\\Data Analysis Projecy\\Udemy_Courses.csv")

# %%
udemy
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# #### Display top 10 rows of the dataset

# %%
udemy.head(10)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# 5    1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# 6    1123184  #7 Piano Hand Coordination: Play Piano Runs in...     True
# 7     768028  * An Integrated Approach to the Fundamentals o...     True
# 8     206592  :::Beginners Guide To Creating Amazing Images ...     True
# 9     738910  [Value Investing] Where White People Keep Thei...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# ...

# %% [markdown]
# #### Check last 5 rows of the dataset

# %%
udemy.tail()
# Out:
#       course_id                                       course_title  is_paid  \
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 3677   120             1566           29            36      All Levels
# 3678    70             1018           12            22  Beginner Level
# 3679    40              723          130            37      All Levels
# 3680  Free              229            0            33      All Levels
# 3681    50               12            1            15      All Levels
#
#      content_duration   published_timestamp              subject
# ...

# %% [markdown]
# #### Find shape of our dataset

# %%
udemy.shape
print("Number of rows ",udemy.shape[0])
print("Number of rows ",udemy.shape[1])
# Out:
# Number of rows  3682
# Number of rows  11

# %% [markdown]
# #### Get the basic information about our dataset

# %%
udemy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %% [markdown]
# #### Check null alues in the dataset

# %%
udemy.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# #### Check duplicates, if exits drop it

# %%
udemy.duplicated().sum()
# Out:
# 6

# %%
udemy.drop_duplicates(inplace=True)

# %%
udemy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Find out number of courses per subjects

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
udemy.subject.value_counts()
# Out:
# Web Development        1199
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
sns.countplot(udemy,x = udemy.subject)
plt.xlabel("Subjects",fontsize = 13)
plt.ylabel("Number of Courses per subjects ",fontsize = 13)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# #### For which levels, udemy courses providing the courses

# %%
udemy.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
udemy['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
sns.countplot(udemy, x = udemy['level'])
plt.xlabel("Levels",fontsize = 13)
plt.ylabel("Number of courses per Level",fontsize = 13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# #### Display the count of paid and free courses

# %%
udemy.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
sns.countplot(udemy, x = udemy['is_paid'].astype('str'))
plt.xlabel("Courses",fontsize = 13)
plt.ylabel("Number of free and paid courses",fontsize = 13)
plt.xticks(rotation=60)
plt.show()

# %%
udemy['is_paid'].value_counts()
# Out:
# True     3366
# False     310
# Name: is_paid, dtype: int64

# %% [markdown]
# #### which course has more lectures (Free or Paid)?

# %%
udemy.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
udemy['num_lectures'].unique()
# Out:
# array([ 68,  41,  47,  43,  32,  21,  25, 123,  17,  20,  15,  16,  18,
#         13,   9,  10,  33,  55,  49, 106,  12,   6,  92,  29,  28,  48,
#         14,  30,  23, 176,   7, 132,  38,   5,  86,  19,  11,  50,  40,
#         67,  37,   8,  26,  53,  36,  56,  80,  27, 114, 126,  22, 316,
#        332,  35,  61, 120,  90,  34, 395, 101,  39,  98,  74,  46,  24,
#        118,  57,  88,  81,  63,  54,  70,  84, 462,  77,  89, 194,  95,
#         91,  82, 119,  71, 136,  45,   4, 133,  83,  42,  52, 111,  65,
#         60,  87,  66,  75, 329, 129,  72,  99, 107,  69, 113,  85,  59,
#         31,  51, 156, 171, 284, 779, 241, 105, 103, 179, 185, 353, 207,
#        454, 197, 138, 162, 227, 131, 130,  58,  73,  62, 112,  44, 160,
#        271, 135, 115, 110, 239,  78, 211, 142, 128, 102, 108,  64, 321,
#        491, 251, 274, 204, 310,  94, 144, 173,  97,  79, 122, 154, 286,
#        444, 174, 224, 100,  93, 124, 212, 159, 104, 187, 527,  76, 309,
# ...

# %%
udemy.groupby(['is_paid']).mean()
# Out:
# C:\Users\jnave\AppData\Local\Temp\ipykernel_33480\2364753127.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   udemy.groupby(['is_paid']).mean()
#              course_id  num_subscribers  num_reviews  num_lectures
# is_paid
# False    691446.970968     11533.951613   425.929032     21.416129
# True     675165.977718      2418.997623   131.364231     41.816993

# %% [markdown]
# #### which course have a higher number of subscribers free or paid?

# %%
udemy.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
sns.barplot(udemy,x = udemy['is_paid'].astype('str'), y = udemy['num_subscribers'])
plt.show()

# %% [markdown]
# #### which level has the highest number of subscribers?

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
sns.barplot(udemy,x = udemy['level'],y = udemy['num_subscribers'])
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# #### Find most popular coure title

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
#based on subscribe we have to find the popular course
udemy[udemy['num_subscribers'].max() == udemy['num_subscribers']]['course_title']
# Out:
# 2230    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# #### Display 10 most popular courses as per number of subscribers

# %%
top_10 = udemy.sort_values(by='num_subscribers',ascending=False).head(10)

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
sns.barplot(x='num_subscribers',y = 'course_title',data=top_10)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# ### Find the course which is having the highest number of reviews

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
plt.figure(figsize=(5
                    ,5))
sns.barplot(x = 'subject',y='num_reviews',data = udemy)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ### Does price affect number of reviews?

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
plt.figure(figsize = (15,5))
sns.scatterplot(x = 'price',y = 'num_reviews',data = udemy)
plt.show()

# %% [markdown]
# ### Find total number of courses related to python

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
udemy[udemy['course_title'].str.contains('python',case=False)]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
len(udemy[udemy['course_title'].str.contains('python',case=False)])
# Out:
# 29

# %% [markdown]
# ### Display 10 Most popular python courses as per number of subscribers

# %%
top_10 = udemy[udemy['course_title'].str.contains('python',case=False)].sort_values(by='num_subscribers',ascending = False).head(10)

# %%
top_10
# Out:
#       course_id                                       course_title  is_paid  \
# 3573      16646                        Web Programming with Python     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2955     822444  Python and Django Full Stack Web Developer Boo...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 3272     938560  The Complete Ethical Hacking Course 2.0: Pytho...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 3460      76052  Try Django 1.9 | Build a Blog and Learn Python...     True
# 2956     477702  Python for Beginners: Python Programming Langu...     True
# 3013     970600                    REST APIs with Flask and Python     True
#
#      price  num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
sns.barplot(y = 'course_title',x = 'num_subscribers',data = top_10)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# ### In which year the highest number of courses were posted?

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
udemy['published_timestamp'] = pd.to_datetime(udemy['published_timestamp'])

# %%
udemy.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments

# %%
udemy['published_timestamp'].dt.year.value_counts()
# Out:
# 2016    1204
# 2015    1014
# 2017     717
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: published_timestamp, dtype: int64

# %%
sns.countplot(udemy,x = udemy['published_timestamp'].dt.year)
# Out:
# <Axes: xlabel='published_timestamp', ylabel='count'>

# %% [markdown]
# ### Display Category-wise count of posted subjects[Year-wise]

# %%
udemy.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments

# %%
udemy.groupby(udemy['published_timestamp'].dt.year)['subject'].count()
# Out:
#                      course_id  course_title  is_paid  price  num_subscribers  \
# subject
# Business Finance          1195          1195     1195   1195             1195
# Graphic Design             602           602      602    602              602
# Musical Instruments        680           680      680    680              680
# Web Development           1199          1199     1199   1199             1199
#
#                      num_reviews  num_lectures  level  content_duration  \
# subject
# Business Finance            1195          1195   1195              1195
# Graphic Design               602           602    602               602
# Musical Instruments          680           680    680               680
# Web Development             1199          1199   1199              1199
#
#                      published_timestamp
# subject
# Business Finance                    1195
# Graphic Design                       602
# Musical Instruments                  680
# ...
