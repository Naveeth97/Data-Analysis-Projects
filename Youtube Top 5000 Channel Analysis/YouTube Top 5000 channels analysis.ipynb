# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
youtube = pd.read_csv("C:\\Users\\jnave\\OneDrive\\Documents\\Data Analysis Projecy\\top-5000-youtube-channels.csv")

# %%
youtube
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
youtube.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# ### Display all rows except the last 5 rows using head method

# %%
youtube.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %% [markdown]
# ### Display all rows except the first 5 rows using tail method

# %%
youtube.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %% [markdown]
# ### Find the shape of our dataset

# %%
print("Number of rows ",youtube.shape[0])
print("Number of columns ",youtube.shape[1])
# Out:
# Number of rows  5000
# Number of columns  6

# %% [markdown]
# ### Get Information about our dataset

# %%
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# ### Get overall statistics about our dataset

# %%
youtube.describe(include = 'all')
# Out:
#         Rank Grade Channel name Video Uploads Subscribers   Video views
# count   5000  5000         5000          5000        5000  5.000000e+03
# unique  5000     6         4993          2286        4612           NaN
# top      1st   B+    Thơ Nguyễn            26         --            NaN
# freq       1  2956            2            17         387           NaN
# mean     NaN   NaN          NaN           NaN         NaN  1.071449e+09
# std      NaN   NaN          NaN           NaN         NaN  2.003844e+09
# min      NaN   NaN          NaN           NaN         NaN  7.500000e+01
# 25%      NaN   NaN          NaN           NaN         NaN  1.862329e+08
# 50%      NaN   NaN          NaN           NaN         NaN  4.820548e+08
# 75%      NaN   NaN          NaN           NaN         NaN  1.124368e+09
# max      NaN   NaN          NaN           NaN         NaN  4.754884e+10

# %% [markdown]
# ### Data cleaning (Replace '--' to NaN)

# %%
youtube.head(3)
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082

# %%
youtube.replace('--',np.nan,regex = True,inplace=True)

# %%
youtube.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %% [markdown]
# ### Check Null values in Dataset

# %%
youtube.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
#showing in percentage
missing = youtube.isnull().sum() * 100 / len(youtube)

# %%
missing
# Out:
# Rank             0.00
# Grade            0.00
# Channel name     0.00
# Video Uploads    0.12
# Subscribers      7.74
# Video views      0.00
# dtype: float64

# %%
sns.heatmap(youtube.isnull())
# Out:
# <Axes: >

# %%
youtube.dropna(axis = 0,inplace=True)

# %%
sns.heatmap(youtube.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Data cleaning(Rank Column)

# %%
youtube.head(3)
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082

# %%
youtube['Rank'].nunique()
# Out:
# 4610

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
youtube['Rank'].unique()
# Out:
# array(['1st', '2nd', '3rd', ..., '4,998th', '4,999th', '5,000th'],
#       dtype=object)

# %%
youtube['Rank'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 4610 entries, 0 to 4999
# Series name: Rank
# Non-Null Count  Dtype
# --------------  -----
# 4610 non-null   object
# dtypes: object(1)
# memory usage: 72.0+ KB

# %%
youtube['Rank'] = youtube['Rank'].astype('str')

# %%
youtube['Rank'] = youtube['Rank'].str[0:-2]

# %%
youtube['Rank'] = youtube['Rank'].str.replace(',','').astype('int')

# %%
youtube.Rank.dtypes
# Out:
# dtype('int32')

# %%
youtube.sample()
# Out:
#       Rank Grade Channel name Video Uploads Subscribers  Video views
# 4198  4199   B+   Mr.VenkatTV          2719      219749     71044404

# %% [markdown]
# ### Data Cleaning in Video Uploads & subscribers

# %%
youtube['Video Uploads'].unique()
# Out:
# array(['82757', '12661', '373', ..., '1735', '706', '3475'], dtype=object)

# %%
youtube['Video Uploads'] = youtube['Video Uploads'].astype('int')

# %%
youtube['Video Uploads'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 4610 entries, 0 to 4999
# Series name: Video Uploads
# Non-Null Count  Dtype
# --------------  -----
# 4610 non-null   int32
# dtypes: int32(1)
# memory usage: 54.0 KB

# %%
youtube['Subscribers'] = youtube['Subscribers'].astype('int')

# %%
youtube.Subscribers.dtypes
# Out:
# dtype('int32')

# %% [markdown]
# ### Data cleaning in Grade Columns

# %%
youtube.sample(5)
# Out:
#       Rank Grade     Channel name  Video Uploads  Subscribers  Video views
# 3897  3898   B+        Sports Tak           5587       849947    128828052
# 1669  1670   A-   Hannah Stocking             76      4637967    739087884
# 2175  2176   B+          Gorillaz            165      4321095   1537024872
# 3997  3998   B+           Kaumudy          21632       725125    329156443
# 1768  1769   A-        BuzzPranks           1332      2392878    987468720

# %%
youtube.Grade.unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
youtube.Grade.nunique()
# Out:
# 5

# %%
#want to change the grade into numerical 
youtube['Grade'].map({'A++ ':5,'A+ ':4,'A ':3,'A- ':2,'B+ ':1})
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
# 5       5
# 6       5
# 7       5
# 8       5
# 9       5
# 10      4
# 11      4
# 12      4
# 13      4
# 14      4
# 15      4
# 16      4
# 18      4
# 19      4
# 20      4
# 21      4
# 22      4
# 23      4
# 24      4
# 25      4
# 26      4
# 27      4
# 28      4
# 29      4
# 30      4
# 31      4
# 32      4
# 33      4
# 34      4
# 35      4
# 36      4
# 37      4
# 38      4
# 39      4
# 40      4
# 41      4
# 42      4
# 43      4
# 44      4
# 45      4
# 46      4
# 47      4
# 48      4
# 49      4
# 50      4
# 51      3
# 52      3
# 53      3
# 54      3
# 55      3
# 56      3
# 57      3
# 58      3
# 59      3
# 60      3
# 61      3
# 62      3
# 63      3
# 64      3
# 65      3
# 66      3
# 67      3
# 68      3
# 69      3
# 70      3
# 71      3
# 72      3
# 73      3
# 74      3
# 75      3
# 76      3
# 77      3
# 78      3
# 79      3
# 80      3
# 81      3
# 82      3
# 83      3
# ...

# %%
youtube['Grade'] = youtube['Grade'].map({'A++ ':5,'A+ ':4,'A ':3,'A- ':2,'B+ ':1})

# %%
youtube.head(2)
# Out:
#    Rank  Grade Channel name  Video Uploads  Subscribers  Video views
# 0     1      5       Zee TV          82757     18752951  20869786591
# 1     2      5     T-Series          12661     61196302  47548839843

# %% [markdown]
# ### Find average views for each channel

# %%
youtube['average_views'] = youtube['Video views']/youtube['Video Uploads']

# %%
youtube.head(10)
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
# 5     6      5                  Movieclips          30243     17149705
# 6     7      5                  netd müzik           8500     11373567
# 7     8      5       ABS-CBN Entertainment         100147     12149206
# 8     9      5             Ryan ToysReview           1140     16082927
# 9    10      5                 Zee Marathi          74607      2841811
#
#    Video views  average_views
# 0  20869786591   2.521815e+05
# 1  47548839843   3.755536e+06
# 2   9793305082   2.625551e+07
# 3  22675948293   8.299216e+05
# 4  26273668433   7.148130e+05
# ...

# %% [markdown]
# ### Find Out Top five channels based on maximum no. of video uploads

# %%
youtube.sort_values(by='Video Uploads',ascending=False).head()
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 3453  3454      1   AP Archive         422326       746325    548619569
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175   2786949164
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       average_views
# 3453    1299.042846
# 1149    4607.769879
# 2223    4666.646928
# 323    10357.902975
# 2956    4966.229622

# %% [markdown]
# ### Find Correlation matrix

# %%
youtube.corr()
# Out:
# C:\Users\jnave\AppData\Local\Temp\ipykernel_7628\1201420011.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   youtube.corr()
#                    Rank     Grade  Video Uploads  Subscribers  Video views  \
# Rank           1.000000 -0.865083      -0.073180    -0.383329    -0.402873
# Grade         -0.865083  1.000000       0.088773     0.429213     0.477423
# Video Uploads -0.073180  0.088773       1.000000     0.011362     0.087830
# Subscribers   -0.383329  0.429213       0.011362     1.000000     0.791241
# Video views   -0.402873  0.477423       0.087830     0.791241     1.000000
# average_views -0.153670  0.155231      -0.064408     0.289386     0.294422
#
#                average_views
# Rank               -0.153670
# Grade               0.155231
# Video Uploads      -0.064408
# ...

# %% [markdown]
# ### Which Grade has a maximum number of video uploads

# %%
youtube.head(5)
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  average_views
# 0  20869786591   2.521815e+05
# 1  47548839843   3.755536e+06
# 2   9793305082   2.625551e+07
# 3  22675948293   8.299216e+05
# 4  26273668433   7.148130e+05

# %%
sns.barplot(x = 'Grade',y='Video Uploads',data = youtube)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %% [markdown]
# ### Which Grade has the highest average views

# %%
sns.barplot(x = 'Grade', y = 'average_views',data=youtube)
# Out:
# <Axes: xlabel='Grade', ylabel='average_views'>

# %% [markdown]
# ### which grade has the highest number of subscribers

# %%
youtube.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  average_views
# 0  20869786591   2.521815e+05
# 1  47548839843   3.755536e+06
# 2   9793305082   2.625551e+07
# 3  22675948293   8.299216e+05
# 4  26273668433   7.148130e+05

# %%
sns.barplot(x = 'Grade',y = 'Subscribers',data = youtube)
# Out:
# <Axes: xlabel='Grade', ylabel='Subscribers'>

# %% [markdown]
# ### Which grade has the highest video views

# %%
youtube.head(2)
# Out:
#    Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 0     1      5       Zee TV          82757     18752951  20869786591
# 1     2      5     T-Series          12661     61196302  47548839843
#
#    average_views
# 0   2.521815e+05
# 1   3.755536e+06

# %%
sns.barplot(x = 'Grade',y='average_views',data = youtube)
# Out:
# <Axes: xlabel='Grade', ylabel='average_views'>
